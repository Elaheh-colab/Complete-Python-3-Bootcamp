# %%
import random
suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 
            'Nine':9, 'Ten':10, 'Jack':11, 'Queen':12, 'King':13, 'Ace':14}

# %%
class Card:
    def __init__(self, suit, rank):
        self.suit = suit
        self.rank = rank
        self.value = values[rank]
    def __str__(self):
        return self.rank + ' of ' + self.suit

# %%
suits[0]
# Out:
# 'Hearts'

# %%
ranks[0]
# Out:
# 'Two'

# %%
Queen_Heart = Card('Hearts','Queen')
Queen_Heart

# %%
print(Queen_Heart)
# Out:
# Queen of Hearts

# %%
Queen_Heart.value
# Out:
# 12

# %%
class Deck:
    def __init__(self):
        self.all_card = []
        for suit in suits:
            for rank in ranks:
                self.all_card.append(Card(suit, rank))
    def shuffle(self):
        random.shuffle(self.all_card)
    def deal_one(self):
        return self.all_card.pop()

# %%
my_deck = Deck()

# %%
len(my_deck.all_card)
# Out:
# 52

# %%
my_deck.all_card[0]

# %%
print(my_deck.all_card[0])
# Out:
# Two of Hearts

# %%
my_deck.shuffle()

# %%
my_deck.all_card[0]

# %%
print(my_deck.all_card[0])
# Out:
# Queen of Spades

# %%
class player():
    def __init__(self, name):
        self.name = name
        self.all_cards = []
    def add_card(self, new_card):
        if type(new_card) == type([]):
            self.all_cards.extend(new_card)
        else:
            self.all_cards.append(new_card)
    def remove_card(self):
        return self.all_cards.pop(0)
    
    def __str__(self):
        return 'player ' + self.name + ' has ' + str(len(self.all_cards))

# %%
player_1 = player('Jose')

# %%
player_1.add_card(Queen_Heart)

# %%
print(player_1)
# Out:
# player Jose has 1

# %%
##Start Game
player_one = player('One')
player_two = player('Two')

# %%
new_deck = Deck()
new_deck.shuffle()

# %%
for x in range(26):
    player_one.add_card(new_deck.deal_one())
    player_two.add_card(new_deck.deal_one())

# %%
len(player_one.all_cards)
# Out:
# 26

# %%
print(player_one.all_cards[0])
# Out:
# Eight of Hearts

# %%
len(player_two.all_cards)
# Out:
# 26

# %%
#play_game
round_num = 0
game_on = True
while game_on:
    round_num += 1
    print(f'Round {round_num}')
    if len(player_one.all_cards) == 0:
        print('Player one doesnt have card')
        print('Player two win')
        game_on = False 
        break
    if len(player_two.all_cards) == 0:
        print('Player two doesnt have card')
        print('Player one win')
        game_on = False 
        break
    #Start a new round and reset the cards on the table
    player_one_card = []
    player_one_card.append(player_one.remove_card())
    print('1111')
    print(len(player_one_card))
    print(player_one_card[0])
    
    player_two_card = []
    player_two_card.append(player_two.remove_card())
    
    
    at_war = True
    
    while at_war:
        #player_one_cards[-1].value > player_two_cards[-1].value:
        if player_one_card[-1].value > player_two_card[-1].value:
            at_war = False
            player_one.add_card(player_one_card)
            player_one.add_card(player_two_card)
        
        elif player_two_card[-1].value > player_one_card[-1].value:
            at_war = False
            player_two.add_card(player_one_card)
            player_two.add_card(player_two_card)
            
        else:
            print('War')
            if len(player_one.all_cards) < 5:
                print('Player one doesnt have enough card')
                print('Player two won the game')
                game_on = False
                break
            elif len(player_two.all_cards) < 5:
                print('Player two doesnt have enough card')
                print('Player one won the game')
                game_on = False
                break
            else:
                for num in range(5):
                    player_one_card.append(player_one.remove_card())
                    player_two_card.append(player_two.remove_card())
# Out:
# Round 1
# 1111
# 1
# Eight of Hearts
# Round 2
# 1111
# 1
# Queen of Spades
# Round 3
# 1111
# 1
# Four of Clubs
# Round 4
# 1111
# 1
# Ace of Diamonds
# Round 5
# 1111
# 1
# Queen of Hearts
# War
# Round 6
# 1111
# 1
# Four of Spades
# Round 7
# 1111
# 1
# Five of Hearts
# Round 8
# 1111
# 1
# Eight of Diamonds
# Round 9
# 1111
# 1
# Two of Diamonds
# War
# Round 10
# 1111
# 1
# King of Hearts
# Round 11
# 1111
# 1
# Seven of Diamonds
# Round 12
# 1111
# 1
# Four of Hearts
# Round 13
# 1111
# 1
# Eight of Clubs
# Round 14
# 1111
# 1
# King of Spades
# Round 15
# 1111
# 1
# Six of Clubs
# Round 16
# 1111
# 1
# Seven of Hearts
# Round 17
# 1111
# 1
# Eight of Hearts
# Round 18
# 1111
# 1
# Six of Spades
# Round 19
# 1111
# 1
# Queen of Spades
# War
# Round 20
# 1111
# 1
# Two of Diamonds
# Round 21
# 1111
# 1
# Nine of Clubs
# Round 22
# 1111
# 1
# Five of Clubs
# Round 23
# 1111
# 1
# Six of Diamonds
# Round 24
# 1111
# 1
# Two of Hearts
# Round 25
# 1111
# 1
# Ten of Hearts
# War
# ...
